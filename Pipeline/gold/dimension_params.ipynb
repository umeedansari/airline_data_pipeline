# %%
table_names=['flights','airports','passengers','bookings']

# %%
dbutils.jobs.taskValues.set('table_name',table_names)

# %%
# %sql
select * from delta.`/Volumes/project/bronze/bronze_files/Airports/data/` limit 3
